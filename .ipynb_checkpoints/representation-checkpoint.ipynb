# %%
from parsers.pdf_parser import parse_pdf
from lxml import etree
#from indexer.indexer import index_patent
#from analyzer.analyzer import analyze_patent

# %%
from split_xml import process_xml_file
# split the xml file with the patents into individual xml files
process_xml_file('patents/ipg071120.xml')

# %%
def extract_text(element):
    """Helper function to extract text from an element and its children."""
    texts = [(element.text or "").strip()]
    for child in element:
        if child.tag == 'claim-ref':
            texts.append((child.text or "").strip())
        if child.tail:
            texts.append((child.tail or "").strip())
    return ' '.join(filter(None, texts))

def print_claim_texts(element, level=0):
    """Recursively print each claim-text, including text after claim-ref."""
    if element.tag == 'claim-text':
        print("  " * level + extract_text(element))
    for child in element:
        print_claim_texts(child, level + 1)

def print_tag_text(tag_name, root):
    for element in root.findall(f'.//{tag_name}'):
        if element.text:
            print(f"{tag_name}: {element.text.strip()}")

def print_citation_doc_numbers(root):
    for idx, doc_number in enumerate(root.xpath('.//citation//patcit//document-id//doc-number'), 1):
        print(f"Citation {idx}: Document Number {doc_number.text.strip()}")

def main():
    try:
        with open('xml_patents/split_1291.xml', 'rb') as file:
            tree = etree.parse(file, etree.XMLParser(recover=True))
        root = tree.getroot()

    except Exception as e:
        print(f"Error parsing XML: {e}")
        return

    patent_details = {
        "Patent Name": './/invention-title',
        "Patent Number": './/doc-number',
        "Patent Abstract": './/abstract/p',
        "Patent U.S. CI. Main classification": './/main-classification'
    }

    for detail, xpath in patent_details.items():
        element = root.find(xpath)
        if element is not None and element.text:
            print(f"{detail}: {element.text.strip()}")
        else:
            print(f"No {detail.lower()} found.")

    print("Patent International Classification:")
    for tag in [
        'classification-level', 'section', 'class', 'subclass',
        'main-group', 'subgroup', 'further-classification'
    ]:
        print_tag_text(tag, root)

    for claim in root.findall('.//claim'):
        print(f"Claim {claim.get('num')}:")
        print_claim_texts(claim)
        print()  # New line between claims

    try:
        print_citation_doc_numbers(root)

    except Exception as e:
        print(f"Error parsing XML: {e}")

if __name__ == "__main__":
    main()
# Out:
# Patent Name: Spring lock interface engagement system
# Patent Number: 07297014
# Patent Abstract: An engagement system having a spring lock design to initially attach the two halves of the system together. After which the use of a multi start Acme lead screw provides a, consistent, low torque means of engagement. Although the engager requires the use of lubrication, to be applied initially, the lube is contained in a sealed environment. This eliminates the risk of contamination to electrical components and eliminates the need to apply additional lube during the products life. Because the present invention allows the ACME threads to be “meshed” at all times, it also eliminates the possibly of cross-threading.
# Patent U.S. CI. Main classification: 439372
# Patent International Classification:
# classification-level: A
# section: H
# class: 01
# subclass: R
# main-group: 13
# subgroup: 62
# further-classification: 439953
# Claim 00001:
#   1. An interface device comprising:
#     a test adapter comprising:
#       a frame; and
#       an engagement mechanism mounted to said frame, said engagement mechanism comprising:
#         a spring lock nut;
#         a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab; and
#         a handle connected to said spring lock nut; and
#     a receiver comprising:
#       a frame;
#       a channel for receiving said spring lock pin; and
#       means within said channel for engaging said at least one locking tab.
#
# Claim 00002:
#   2. An interface device according to claim 1 wherein said test adapter further comprises an alignment pin and said receiver further comprising a guide channel for receiving said alignment pin.
#
# Claim 00003:
#   3. An interface device according to claim 1 wherein said spring lock pin comprises a body, said at least one locking tab, and a blind alignment nose.
#
# Claim 00004:
#   4. An interface device according to claim 1 wherein said housing provides a sealed environment for said lead screw drive.
#
# Claim 00005:
#   5. An interface device according to claim 1 wherein said at least one locking tab comprises four locking tabs.
#
# Claim 00006:
#   6. An interface device according to claim 1 , wherein
#     said test adapter further comprises a cover attached to said frame, said cover having an opening therein; and
#     said handle comprises a body and a stem, wherein said body is located outside said cover and said stem extends through said opening in said cover and connects to said lead screw drive.
#
# Claim 00007:
#   7. An interface device according to claim 1 , wherein said test adapter further comprises a plate connected to said frame and a collar connected to said plate.
#
# Claim 00008:
#   8. An interface device according to claim 7 wherein said collar comprises a clamp for clamping wires.
#
# Claim 00009:
#   9. An interface device according to claim 6 wherein said spring lock nut has a pair of flat sides for connecting to said stem of said handle.
#
# Claim 00010:
#   10. An interface device according to claim 9 wherein said spring lock nut further comprises means for connecting said handle to said spring lock nut.
#
# Claim 00011:
#   11. An interface device according to claim 1 further comprising means for locking said handle in a closed position.
#
# Claim 00012:
#   12. An interface device according to claim 1 further comprising means for locking said handle in an open position.
#
# Claim 00013:
#   13. An interface device according to claim 1 wherein said threads on said Acme screw comprise multi-start threads.
#
# Claim 00014:
#   14. An interface comprising:
#     a test adapter comprising:
#       a frame; and
#       an engagement mechanism mounted to said frame, said engagement mechanism comprising:
#         a spring lock nut;
#         a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing and having threads for engaging with said interior threads of said housing, and a spring lock pin having at least one locking tab; and
#         a handle connected to said spring lock nut; and
#     a receiver comprising:
#       a frame;
#       a channel for receiving said spring lock pin; and
#       a ridge in said channel for engaging said at least one locking tab;
#     wherein during engagement of said test adapter with said receiver, said spring lock pin initially connects said test adapter to said receiver by said at least one locking tab engaging with said ridge in said channel and said lead screw drive draws said test adapter and said receiver together when said handle is turned.
#
# Claim 00015:
#   15. An interface according to claim 14 wherein said test adapter comprises a plurality of guide pins and said receive further comprises a plurality of guide holes for receiving said guide pins.
#
# Claim 00016:
#   16. An interface device comprising:
#     a test adapter comprising:
#       a frame; and
#       an engagement mechanism mounted to said frame, said engagement mechanism comprising:
#         a spring lock nut;
#         a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing and having threads for engaging with said interior threads of said housing, and a spring lock pin having at least one locking tab; and
#         a handle connected to said spring lock nut; and
#     a receiver comprising:
#       a frame;
#       a channel for receiving said spring lock pin; and
#       a groove in said channel for engaging said at least one locking tab;
#     wherein during engagement of said test adapter with said receiver, said spring lock pin initially connects said test adapter to said receiver by said at least one locking tab engaging with said groove in said channel and said lead screw drive draw said test adapter and said receiver together when said handle is turned.
#
# Citation 1: Document Number 3166369
# Citation 2: Document Number 3419842
# Citation 3: Document Number 4212508
# Citation 4: Document Number 4213666
# Citation 5: Document Number 4329005
# Citation 6: Document Number 4655530
# Citation 7: Document Number 5037321
# Citation 8: Document Number 5103378
# Citation 9: Document Number 5227718
# Citation 10: Document Number 5420519
# Citation 11: Document Number 5562458
# Citation 12: Document Number 5576631
# Citation 13: Document Number 5633597
# Citation 14: Document Number 5820401
# Citation 15: Document Number 5850147
# Citation 16: Document Number 5936421
# Citation 17: Document Number 5942906
# Citation 18: Document Number 5966023
# Citation 19: Document Number 5993255
# Citation 20: Document Number 6116942
# Citation 21: Document Number 6257918
# Citation 22: Document Number 6530801
# Citation 23: Document Number 6547587
# Citation 24: Document Number 6781391
# Citation 25: Document Number 6824405
# Citation 26: Document Number 6869321
# Citation 27: Document Number 6872006
# Citation 28: Document Number 6882138
# Citation 29: Document Number 6948952
# Citation 30: Document Number 7091415
# Citation 31: Document Number 2006/0205253

# %%
from preprocess import extract_and_convert_to_json, json_to_patent
import json

patent_number = '07297014'

json_data, patent_as_class = extract_and_convert_to_json(f'xml_patents_wn/{patent_number}.xml')
#print(json_data)
data_dict = json.loads(json_data)


with open(f'json_patents/{patent_number}.json', 'w') as file:
    json.dump(data_dict, file, indent=4)

with open(f'json_patents/{patent_number}.json', 'r') as file:
    data = json.load(file)
    
claims_subset = patent.claims[:1]
print(json.dumps(claims_subset, indent=4))
# Out:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. An interface device comprising:",
#         "components": [
#             {
#                 "component": "a test adapter comprising:",
#                 "subcomponents": [
#                     "a frame; and",
#                     "an engagement mechanism mounted to said frame, said engagement mechanism comprising:",
#                     "a spring lock nut;",
#                     "a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab; and",
#                     "a handle connected to said spring lock nut; and"
#                 ]
#             },
#             {
#                 "component": "a frame; and",
#                 "subcomponents": []
#             },
#             {
#                 "component": "an engagement mechanism mounted to said frame, said engagement mechanism comprising:",
#                 "subcomponents": [
#                     "a spring lock nut;",
#                     "a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab; and",
#                     "a handle connected to said spring lock nut; and"
#                 ]
#             },
#             {
#                 "component": "a spring lock nut;",
#                 "subcomponents": []
#             },
#             {
#                 "component": "a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab; and",
#                 "subcomponents": []
#             },
#             {
#                 "component": "a handle connected to said spring lock nut; and",
#                 "subcomponents": []
#             },
#             {
#                 "component": "a receiver comprising:",
#                 "subcomponents": [
#                     "a frame;",
#                     "a channel for receiving said spring lock pin; and",
#                     "means within said channel for engaging said at least one locking tab."
#                 ]
#             },
#             {
#                 "component": "a frame;",
#                 "subcomponents": []
#             },
#             {
#                 "component": "a channel for receiving said spring lock pin; and",
#                 "subcomponents": []
#             },
#             {
#                 "component": "means within said channel for engaging said at least one locking tab.",
#                 "subcomponents": []
#             }
#         ]
#     }
# ]

# %%
def convert_all_xml_to_json(xml_directory, json_directory):
    os.makedirs(json_directory, exist_ok=True)
    
    for file_name in os.listdir(xml_directory):
        if file_name.endswith('.xml'):
            patent_number = file_name.split('.')[0]
            json_data, patent_as_class = extract_and_convert_to_json(f'{xml_directory}/{file_name}')
            data_dict = json.loads(json_data)
            
            with open(f'{json_directory}/{patent_number}.json', 'w') as file:
                json.dump(data_dict, file, indent=4)
                
            #patent = json_to_patent(json.dumps(data_dict))
            #print(f'Claims for {patent_number}:')
            #print(json.dumps(patent.claims, indent=4))

# folders
xml_directory = 'xml_patents_wn'
json_directory = 'json_patents'

convert_all_xml_to_json(xml_directory, json_directory)
# Out:
# Claims for D0555326:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for clergy collar, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555327:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a work glove, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555328:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a belt configuration, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555329:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a multi-piece bra, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555330:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "We claim the ornamental design for a hooded scarf, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555331:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a rear panel for a ponytail cap, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555332:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a double upper athleisure shoe, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555333:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a double tongue athleisure shoe, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555334:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for footwear with decorative gemstones, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555335:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a boot, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555336:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a portion of an article of footwear, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555337:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a footwear outsole, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555338:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for an outsole for a shoe, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555339:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a shoe outsole, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555340:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a shoe outsole, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555341:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design of a shoe insole, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555342:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a footwear upper, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555343:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for portion of a footwear upper, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555344:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a portion of a footwear upper, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555345:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for portion of a footwear upper, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555346:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental portion of a footwear upper, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555347:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a portion of a shoe upper, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555348:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a footwear mid-sole, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555349:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a multiple collapsible umbrella, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555350:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cane, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555351:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "We claim the ornamental design for a mouse pad carrying case, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555352:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle tote, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555353:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wrist band device holder, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555354:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for tool holder, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555355:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a purse, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555356:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a storage case, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555357:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a tool box, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555358:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a tow strap carrier and dispenser, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555359:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The new and ornamental design for an toothbrush, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555360:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for an oil brush, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555361:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wire brush, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555362:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wire brush, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555363:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wire brush, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555364:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a nonwoven fabric, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555365:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a support, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555366:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an over-the-door hook rack, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555367:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a partition for beauty salon, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555368:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a seating unit, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555369:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a chair, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555370:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a foldable chair/table, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555371:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim, the ornamental design for a seat, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555372:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a chair, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555373:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for baby swing, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555374:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a garden swing, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555375:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim, the ornamental design for a seat, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555376:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the design for a chair, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555377:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "We claim the ornamental design for seating unit, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555378:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a folding lounge chair, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555379:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a chair, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555380:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for the stacking chair, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555381:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for chair, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555382:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a sofa, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555383:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for divan, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555384:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a divan, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555385:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a sofa, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555386:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a sofa, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555387:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a sofa, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555388:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a flowerpot stand, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555389:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a planter caddy, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555390:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a disc divider, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555391:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a compact disc holder, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555392:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a display and control unit, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555393:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an dresser, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555394:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wood vertical file, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555395:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an eyewear display, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555396:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a display case, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555397:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for audio video shelving unit, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555398:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a contour shelf, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555399:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for storage cube, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555400:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a desk, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555401:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a stacking side table, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555402:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a base of children safety seat, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555403:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a conically-shaped glass for an outside wedge-style display case, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555404:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a shower organizer, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555405:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a holder of dental brushes with tooth paste squeezer, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555406:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a magnetically held household display and storage device for menus, recipes, notes and the like, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555407:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bath mat, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555408:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a travel sleeping pillow, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555409:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a car seat blanket, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555410:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a drinking straw, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555411:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a double-sided fuel pump beverage dispenser, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555412:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a coffee brewing apparatus, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555413:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an automatic coffee maker, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555414:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a coffee maker, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555415:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a coffee maker, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555416:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a carafe with lid, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555417:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for cooking apparatus, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555418:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cooking vessel with a decorative medallion, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555419:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for the one-handle tray, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555420:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a mixing machine, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555421:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cookware handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555422:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a saucepan handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555423:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cookware handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555424:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cookware side handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555425:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cookware side handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555426:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a turkey fryer stand, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555427:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a food processing container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555428:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a non-spill cup, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555429:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a hurricane drink container, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555430:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a mug, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555431:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a camping, kitchen accessory, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555432:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a contoured eating utensil, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555433:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a flatware handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555434:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design of a juice extractor appliance, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555435:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a spice grinder, substantially as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555436:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a chef's thermometer fork, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555437:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a food serving utensil, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555438:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "We claim the ornamental design for a utensil, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555439:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a funnel, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555440:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an interconnectable module for a tree surround, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555441:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a reservoir for a tree and plant watering system, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555442:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for the herb scissors, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555443:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a serrated blade, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555444:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a saw blade, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555445:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design of a T-handle hex wrench, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555446:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a blow torch, substantially as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555447:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a lighted, retractable bottle opener, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555448:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an can opener, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555449:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a sander tool, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555450:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cordless saw, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555451:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a portable electric hammer drill, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555452:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cutting head, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555453:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cutting head, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555454:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a clamp, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555455:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a multi function tool, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555456:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a lever, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555457:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a decorative key, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555458:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a face plate for switch panel, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555459:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wall mount bracket, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555460:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design of a hook member, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555461:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for the drum stick holder, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555462:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for dual arm pegboard hook, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555463:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a hook rack, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555464:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a hook rack, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555465:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a hanger plug, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555466:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a multiple object hanger, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555467:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a door supporting bracket, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555468:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a combination mounting bracket and support tray, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555469:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a hub structure, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555470:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a magnetic fastener, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555471:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a carton with an end aperture, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555472:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vacuum pump packaging, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555473:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "We claim the ornamental design for a covering for a container of three tennis balls, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555474:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a product dispensing package, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555475:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a multiple compartment square food container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555476:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for packaging, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555477:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a closure, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555478:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a lid to a jar, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555479:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for the ink bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555480:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cosmetic container and cap, substantially as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555481:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a motor oil bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555482:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555483:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555484:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555485:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555486:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555487:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "We claim the ornamental design for a container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555488:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555489:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a graduated bottle for liquid, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555490:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a product dispenser, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555491:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555492:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555493:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555494:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a plastic container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555495:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a \u201cbeverage bottle\u201d, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555496:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a water bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555497:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555498:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555499:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a container label panel, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555500:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555501:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555502:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555503:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555504:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555505:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bottle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555506:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for dispenser with non-round body, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555507:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a dispenser for cosmetics, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555508:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a dispenser of a container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555509:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a tube, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555510:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an evacuable, resealable bag, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555511:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a lint card package, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555512:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a candy container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555513:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a combined fry and food scoop with condiment cells, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555514:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a metal can, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555515:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a watch, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555516:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wrist watch, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555517:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wrist watch case, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555518:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a watch, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555519:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a watch, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555520:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a watch case, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555521:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a watch, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555522:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a food timer device, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555523:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design of a level, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555524:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle data kiosk, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555525:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a test instrument, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555526:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cabinet bath with round window, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555527:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a carbon monoxide detector for automatically opening garage doors, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555528:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for mountable security detector, as shown and described herein.",
#         "components": []
#     }
# ]
# Claims for D0555529:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a multi chambered whistle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555530:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a game call, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555531:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for identification necklace, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555532:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a ring, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555533:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a pendant, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555534:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for the jewelry setting, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555535:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a plant shaping device, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555536:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a door figurine, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555537:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a buckle guard, substantially as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555538:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an \u201cslide,\u201d as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555539:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a surface configuration of a vehicle, toy, and/or other replicas, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555540:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a surface configuration of a vehicle, toy, and/or other replicas, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555541:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an automobile, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555542:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for, a rear portion of a motorcycle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555543:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for, a motor scooter, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555544:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for, a motor scooter, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555545:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a land-based towing device, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555546:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a quick release lever for a bicycle hub, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555547:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an outer link for a rear derailleur, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555548:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle frame rail, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555549:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for: trailer hitch, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555550:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle grille, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555551:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle rear bumper cover, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555552:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle rear bumper cover, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555553:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle hood, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555554:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle hood, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555555:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for calipers for disc brakes, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555556:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle fender, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555557:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle fender, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555558:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a mirror, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555559:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle door, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555560:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a surface configuration of a safety cell for a vehicle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555561:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a radiator end cap, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555562:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a front face of a floor mat, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555563:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a floor mat, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555564:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a decorative vehicle hubcap with beveled rim, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555565:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wheel, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555566:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a front face of a vehicle wheel, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555567:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a front face of a vehicle wheel, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555568:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for vehicle-wheel front face, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555569:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a riser block, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555570:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bow of a ship, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555571:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for anti-skid mat for accessories in an automobile, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555572:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a mirror cover, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555573:
# [
#     {
#         "claim_number": "CLM-00001",
# ...
#         "components": []
#     }
# ]
# Claims for D0555812:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a post, is shown and described herein.",
#         "components": []
#     }
# ]
# Claims for D0555813:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a wall plate side with snap lock as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555814:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a floorboard, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555815:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle fog lamp, as shown and described in FIGS. 1-14.",
#         "components": []
#     }
# ]
# Claims for D0555816:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vehicle tail light lens, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555817:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for the bicycle lighting set, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555818:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a manually chargeable flashlight, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555819:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a worklight, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555820:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for rechargeable torch with emergency light and nightlight, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555821:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a luminaire housing, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555822:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for the fluorescent light reflector with conical top, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555823:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a light shade, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555824:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a lamp assembly, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555825:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a trim for a light fixture, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555826:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a back plate for lighting fixture, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555827:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a back plate for lighting fixture, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555828:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a dentifrice, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555829:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for toothpaste, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555830:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a sachet, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555831:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a silicone rubber head for cosmetic purposes, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555832:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a hair extension removal tool, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555833:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a disk used for a hair extension application process, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555834:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "We claim the ornamental design for the razor handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555835:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for \u201ca powder container,\u201d as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555836:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a padded neck collar, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555837:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a mask, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555838:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a mace glove, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555839:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a wrist band, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555840:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cattle waterer, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555841:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a hexagonal roofed bird feeder with a solar powered lamp, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555842:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a rectangular bird feeder with a solar powered set, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555843:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a cat scratch box, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555844:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a pet toy, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555845:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for pet steps, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555846:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a door for dishwasher, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555847:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a tube cleaning machine, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555848:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vacuum cleaner, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555849:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vacuum cleaner, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555850:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vacuum cleaner, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555851:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vacuum cleaner, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555852:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a vacuum cleaner, as shown.",
#         "components": []
#     }
# ]
# Claims for D0555853:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a pool cleaning net, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555854:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a laundry basket, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555855:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a handle for a squeegee or the like, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555856:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim the ornamental design for a scraper tool with pivoting handle, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555857:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cleaning implement, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555858:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "I claim, the ornamental design for a water bucket for portable irrigator, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555859:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bucket with crown rim motif, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555860:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a bucket with rounded rim motif, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555861:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a trash container, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555862:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a receptacle with rectangular shape in plan, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555863:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cylindrical receptacle with narrow aspect, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555864:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for garbage can, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555865:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for garbage can, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555866:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for garbage can, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555867:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for garbage can, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555868:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for garbage can, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555869:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cleaning trolley, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555870:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a cleaning trolley, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555871:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a stand, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555872:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design of a handle for a dolly cart, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555873:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for an extension piece for flow track, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555874:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a winch, as shown and described.",
#         "components": []
#     }
# ]
# Claims for D0555875:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "The ornamental design for a graveside keepsake storing device, as shown and described.",
#         "components": []
#     }
# ]
# Claims for PP018221:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct variety of Cactaceae plant, substantially as herein shown and described.",
#         "components": []
#     }
# ]
# Claims for PP018222:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct cultivar of",
#         "components": []
#     }
# ]
# Claims for PP018223:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct variety of",
#         "components": []
#     }
# ]
# Claims for PP018224:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct variety of peach tree, substantially as herein shown and described.",
#         "components": []
#     }
# ]
# Claims for PP018225:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct variety of",
#         "components": []
#     }
# ]
# Claims for PP018226:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct cultivar of grapevine plant as shown and described herein.",
#         "components": []
#     }
# ]
# Claims for PP018227:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct",
#         "components": []
#     }
# ]
# Claims for PP018228:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct variety of",
#         "components": []
#     }
# ]
# Claims for PP018229:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct cultivar of",
#         "components": []
#     }
# ]
# Claims for PP018230:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct cultivar of",
#         "components": []
#     }
# ]
# Claims for PP018231:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct Poinsettia plant named \u2018PER8603\u2019 as illustrated and described.",
#         "components": []
#     }
# ]
# Claims for PP018232:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct Poinsettia plant named \u2018PER2004\u2019 as illustrated and described.",
#         "components": []
#     }
# ]
# Claims for PP018233:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct",
#         "components": []
#     }
# ]
# Claims for PP018234:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct",
#         "components": []
#     }
# ]
# Claims for PP018235:
# [
#     {
#         "claim_number": "CLM-00001",
#         "preamble": "1. A new and distinct",
#         "components": []
#     }
# ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 22
#      19 xml_directory = 'xml_patents_wn'
#      20 json_directory = 'json_patents'
# ---> 22 convert_all_xml_to_json(xml_directory, json_directory)
#
# Cell In[82], line 11, in convert_all_xml_to_json(xml_directory, json_directory)
#       8 data_dict = json.loads(json_data)
#      10 with open(f'{json_directory}/{patent_number}.json', 'w') as file:
# ---> 11     json.dump(data_dict, file, indent=4)
#      13 # Optional: Print the claims for each patent
#      14 patent = json_to_patent(json.dumps(data_dict))
#
# KeyboardInterrupt:

# %%
import re
import json
from itertools import islice

def clean_text(text, patterns):
    for pattern in patterns:
        text = re.sub(pattern, '', text)
    return text

# Define regex patterns
patterns_preamble = [r'^\d+\.\s*', r'comprising:$', r'^(a |an |An |A)']
patterns_component = [r'comprising:$', r'; and$', r'^(a |an |An |A)']
patterns_subcomponent = [r'^(comprising\s+|a\s+|an\s+|\d+\s+)*', r'comprising:$', r'; and$', r'^(a |an |An |A)']

# Initialize questions dictionary
questions_dict = {}

claims = patent.claims

for claim in claims:
    preamble_key = claim["preamble"]
    preamble = clean_text(claim["preamble"], patterns_preamble)
    components = claim.get("components", [])
    
    if preamble not in questions_dict:
        questions_dict[preamble_key] = {}
        
    if not components:
        # If only a preamble exists
        if '' not in questions_dict[preamble_key]:
            questions_dict[preamble_key][''] = {
                '': [f"What is the role of {preamble}?",
                    f"How is {preamble} utilized?",
                    f"What outcomes are produced by {preamble}?",
                    f"What alternative components can substitute {preamble}?"]
            }
    else:
        for component_data in components:
            component_key = component_data["component"]
            component = clean_text(component_data["component"], patterns_component)
            subcomponents = component_data.get("subcomponents", [])
            
            if component not in questions_dict[preamble_key]:
                questions_dict[preamble_key][component_key] = {}
                
            if not subcomponents:
                if '' not in questions_dict[preamble_key][component_key]:
                    questions_dict[preamble_key][component_key][''] = [f"What is the role of the {component} of the {preamble}?",
                                                              f"How is the {component} of the {preamble} utilized?",
                                                              f"What outcomes are produces by the {component} of the {preamble}?",
                                                              f"What alternative components can substitute the {component} of the {preamble}?"]
            else:
                for subcomponent in subcomponents:
                    subcomponent_key = subcomponent
                    subcomponent = clean_text(subcomponent, patterns_subcomponent)
                    
                    if subcomponent not in questions_dict[preamble_key][component_key]:
                        questions_dict[preamble_key][component_key][subcomponent_key] = []
                    
                    # Add questions only if the list is empty
                    if not questions_dict[preamble_key][component_key][subcomponent_key]:
                        questions_dict[preamble_key][component_key][subcomponent_key].extend([
                            f"What is the role of the {subcomponent} in the {component} of the {preamble}?",
                            f"How is the {subcomponent} utilized within the {component} of the {preamble}?",
                            f"What outcomes are produced by {subcomponent} in the {component} of the {preamble}?",
                            f"What alternative components can substitute {subcomponent} in the {component} of the {preamble}?"
                        ])
                        
first_three_items = dict(islice(questions_dict.items(), 1))
print(json.dumps(first_three_items, indent=4))
# Out:
# {
#     "1. An interface device comprising:": {
#         "a test adapter comprising:": {
#             "a frame; and": [
#                 "What is the role of the frame in the test adapter  of the interface device ?",
#                 "How is the frame utilized within the test adapter  of the interface device ?",
#                 "What outcomes are produced by frame in the test adapter  of the interface device ?",
#                 "What alternative components can substitute frame in the test adapter  of the interface device ?"
#             ],
#             "an engagement mechanism mounted to said frame, said engagement mechanism comprising:": [
#                 "What is the role of the engagement mechanism mounted to said frame, said engagement mechanism  in the test adapter  of the interface device ?",
#                 "How is the engagement mechanism mounted to said frame, said engagement mechanism  utilized within the test adapter  of the interface device ?",
#                 "What outcomes are produced by engagement mechanism mounted to said frame, said engagement mechanism  in the test adapter  of the interface device ?",
#                 "What alternative components can substitute engagement mechanism mounted to said frame, said engagement mechanism  in the test adapter  of the interface device ?"
#             ],
#             "a spring lock nut;": [
#                 "What is the role of the spring lock nut; in the test adapter  of the interface device ?",
#                 "How is the spring lock nut; utilized within the test adapter  of the interface device ?",
#                 "What outcomes are produced by spring lock nut; in the test adapter  of the interface device ?",
#                 "What alternative components can substitute spring lock nut; in the test adapter  of the interface device ?"
#             ],
#             "a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab; and": [
#                 "What is the role of the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab in the test adapter  of the interface device ?",
#                 "How is the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab utilized within the test adapter  of the interface device ?",
#                 "What outcomes are produced by lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab in the test adapter  of the interface device ?",
#                 "What alternative components can substitute lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab in the test adapter  of the interface device ?"
#             ],
#             "a handle connected to said spring lock nut; and": [
#                 "What is the role of the handle connected to said spring lock nut in the test adapter  of the interface device ?",
#                 "How is the handle connected to said spring lock nut utilized within the test adapter  of the interface device ?",
#                 "What outcomes are produced by handle connected to said spring lock nut in the test adapter  of the interface device ?",
#                 "What alternative components can substitute handle connected to said spring lock nut in the test adapter  of the interface device ?"
#             ]
#         },
#         "a frame; and": {
#             "": [
#                 "What is the role of the frame of the interface device ?",
#                 "How is the frame of the interface device  utilized?",
#                 "What outcomes are produces by the frame of the interface device ?",
#                 "What alternative components can substitute the frame of the interface device ?"
#             ]
#         },
#         "an engagement mechanism mounted to said frame, said engagement mechanism comprising:": {
#             "a spring lock nut;": [
#                 "What is the role of the spring lock nut; in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "How is the spring lock nut; utilized within the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "What outcomes are produced by spring lock nut; in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "What alternative components can substitute spring lock nut; in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?"
#             ],
#             "a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab; and": [
#                 "What is the role of the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "How is the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab utilized within the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "What outcomes are produced by lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "What alternative components can substitute lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?"
#             ],
#             "a handle connected to said spring lock nut; and": [
#                 "What is the role of the handle connected to said spring lock nut in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "How is the handle connected to said spring lock nut utilized within the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "What outcomes are produced by handle connected to said spring lock nut in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?",
#                 "What alternative components can substitute handle connected to said spring lock nut in the engagement mechanism mounted to said frame, said engagement mechanism  of the interface device ?"
#             ]
#         },
#         "a spring lock nut;": {
#             "": [
#                 "What is the role of the spring lock nut; of the interface device ?",
#                 "How is the spring lock nut; of the interface device  utilized?",
#                 "What outcomes are produces by the spring lock nut; of the interface device ?",
#                 "What alternative components can substitute the spring lock nut; of the interface device ?"
#             ]
#         },
#         "a lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab; and": {
#             "": [
#                 "What is the role of the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab of the interface device ?",
#                 "How is the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab of the interface device  utilized?",
#                 "What outcomes are produces by the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab of the interface device ?",
#                 "What alternative components can substitute the lead screw drive comprising a housing having interior threads, an Acme lead screw in said housing, and a spring lock pin having at least one retractable locking tab of the interface device ?"
#             ]
#         },
#         "a handle connected to said spring lock nut; and": {
#             "": [
#                 "What is the role of the handle connected to said spring lock nut of the interface device ?",
#                 "How is the handle connected to said spring lock nut of the interface device  utilized?",
#                 "What outcomes are produces by the handle connected to said spring lock nut of the interface device ?",
#                 "What alternative components can substitute the handle connected to said spring lock nut of the interface device ?"
#             ]
#         },
#         "a receiver comprising:": {
#             "a frame;": [
#                 "What is the role of the frame; in the receiver  of the interface device ?",
#                 "How is the frame; utilized within the receiver  of the interface device ?",
#                 "What outcomes are produced by frame; in the receiver  of the interface device ?",
#                 "What alternative components can substitute frame; in the receiver  of the interface device ?"
#             ],
#             "a channel for receiving said spring lock pin; and": [
#                 "What is the role of the channel for receiving said spring lock pin in the receiver  of the interface device ?",
#                 "How is the channel for receiving said spring lock pin utilized within the receiver  of the interface device ?",
#                 "What outcomes are produced by channel for receiving said spring lock pin in the receiver  of the interface device ?",
#                 "What alternative components can substitute channel for receiving said spring lock pin in the receiver  of the interface device ?"
#             ],
#             "means within said channel for engaging said at least one locking tab.": [
#                 "What is the role of the means within said channel for engaging said at least one locking tab. in the receiver  of the interface device ?",
#                 "How is the means within said channel for engaging said at least one locking tab. utilized within the receiver  of the interface device ?",
#                 "What outcomes are produced by means within said channel for engaging said at least one locking tab. in the receiver  of the interface device ?",
#                 "What alternative components can substitute means within said channel for engaging said at least one locking tab. in the receiver  of the interface device ?"
#             ]
#         },
#         "a frame;": {
#             "": [
#                 "What is the role of the frame; of the interface device ?",
#                 "How is the frame; of the interface device  utilized?",
#                 "What outcomes are produces by the frame; of the interface device ?",
#                 "What alternative components can substitute the frame; of the interface device ?"
#             ]
#         },
#         "a channel for receiving said spring lock pin; and": {
#             "": [
#                 "What is the role of the channel for receiving said spring lock pin of the interface device ?",
#                 "How is the channel for receiving said spring lock pin of the interface device  utilized?",
#                 "What outcomes are produces by the channel for receiving said spring lock pin of the interface device ?",
#                 "What alternative components can substitute the channel for receiving said spring lock pin of the interface device ?"
#             ]
#         },
#         "means within said channel for engaging said at least one locking tab.": {
#             "": [
#                 "What is the role of the means within said channel for engaging said at least one locking tab. of the interface device ?",
#                 "How is the means within said channel for engaging said at least one locking tab. of the interface device  utilized?",
#                 "What outcomes are produces by the means within said channel for engaging said at least one locking tab. of the interface device ?",
#                 "What alternative components can substitute the means within said channel for engaging said at least one locking tab. of the interface device ?"
#             ]
#         }
#     }
# }

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.core.credentials import AzureKeyCredential

os.environ["AZURE_INFERENCE_CREDENTIAL"] = "bgPmgSmdESRKu3Qq4zsZ8TgGSL2RaPLN"
api_key = os.getenv("AZURE_INFERENCE_CREDENTIAL", '')
if not api_key:
    raise Exception("A key should be provided to invoke the endpoint")
    
client = ChatCompletionsClient(
    endpoint='https://Phi-3-5-MoE-instruct-gaqxj.eastus2.models.ai.azure.com',
    credential=AzureKeyCredential(api_key)
)

def structure_to_string(data):
    claim_strings = []
    for claim in data:
        claim_str = f"{claim['claim_number']}\n{claim['preamble']}\n"
        for component in claim['components']:
            claim_str += f"  {component['component']}\n"
            for subcomponent in component['subcomponents']:
                claim_str += f"    {subcomponent}\n"
        claim_strings.append(claim_str)
    return "\n".join(claim_strings)

def generate_answers(abstract, patent_title, claims, questions):
    title_example = "Apparatus for docking a printed circuit board"
    question_example = "What is the role of a guide plate selectively securable in a position adjacent to a first electronic connector, the guide plate including at least one linear slot of the apparatus?"
    answer_example = "The goal is to select and secure the electric circuit board in a designated location."
    question_example1 = "What alternative components can substitute the guide plate selectively securable in a position adjacent to a first electronic connector, the guide plate including at least one linear slot of the apparatus?"
    answer_example1 = "Alternative componets may include adjustable brackets, spring clips, guide rails, magnetic strips, or standarized slots or holes."
    #print(title_example)

    # Initialize messages with the example
    initial_messages = [
        {
            "role": "system",
            "content": "You are a patent expert and answer questions according to the doctrine of equivalents in a brief and direct manner in less than one hundred words."
        },
        {
            "role": "user",
            "content": f"{question_example}"
        },
        {
            "role": "assistant",
            "content": f"{answer_example}"
        },
        {
            "role": "user",
            "content": f"{question_example1}"
        },
        {
            "role": "assistant",
            "content": f"{answer_example1}"
        }
    ]

    answers = []
    for i, question in enumerate(questions):
        # Include the first example to follow the few-shot strategy
        messages = initial_messages + [
            {
                "role": "user",
                "content": f"The patent title is: {patent_title}. The patent abstract is: {abstract}. {question}"
            }
        ]

        payload = {
            "messages": messages,
            "max_tokens": 100, 
            "temperature": 0.5, 
            "top_p": 0.1,
            "presence_penalty": 0.5,
            "frequency_penalty": 0.5 
        }
        #print("payload", payload)
        response = client.complete(payload)
        #print("the response to the questions are:", response.choices[0].message.content)
        answers.append(response.choices[0].message.content)
    #print(json.dumps(answers, indent=4))
    return answers


def query_patent(patent, questions):
    answers = {}
    claims = patent.claims
    abstract = patent.abstract
    patent_title = patent.title

    for preamble in questions:
        if preamble not in answers:
            answers[preamble] = {}

        # Check if there are components under the preamble
        components = questions[preamble]
        if not components:
            # Directly answer if there are no components
            answers[preamble] = generate_answers(
                abstract, patent_title, structure_to_string(claims), preamble
            )
            continue
        
        for component in components:
            if component not in answers[preamble]:
                answers[preamble][component] = {}

            # Check if there are subcomponents under the component
            subcomponents = questions[preamble][component]
            if not subcomponents:
                # Directly answer if there are no subcomponents
                answers[preamble][component] = generate_answers(
                    abstract, patent_title, structure_to_string(claims), component
                )
                continue

            for subcomponent in subcomponents:
                if subcomponent not in answers[preamble][component]:
                    answers[preamble][component][subcomponent] = generate_answers(
                        abstract, patent_title, structure_to_string(claims),
                        questions[preamble][component][subcomponent]
                    )


    return answers

answers = query_patent(patent, questions_dict)
with open(f'question_feature/{patent.document_number}.json', 'w') as file:
    json.dump(answers, file, indent=4)

# %%
from general_patent_query import query_patent_general

patent_questions = ["What is the essential function of the product or process?",
                    "How does the product or process operate?",
                    "What results does this product or process achieve?",
                    "What ingredients, materials, or processes are alternatives that can work in the same way?"
                   ]

answers = query_patent_general(client, patent, patent_questions)

combined_data = {
    "title": patent.title,
    "abstract": patent.abstract,
    "claims": patent.claims,
    "answers": answers
}

# Write the combined data to a JSON file
with open(f'question_patent/{patent.document_number}.json', 'w') as file:
    json.dump(combined_data, file, indent=4)

print(answers)
# Out:
# [' The essential function of the patented spring lock interface engagement system is to securely attach two components, typically a test adapter and a receiver, using a spring lock nut and an Acme lead screw mechanism. This system ensures precise alignment, consistent low torque engagement, and protection against contamination for electrical components.', ' The patented spring lock interface engagement system operates by initially attaching a test adapter and receiver using a spring lock nut and an Acme lead screw mechanism. The handle connected to the spring lock nut is turned, causing the lead screw to draw the adapter and receiver together. This ensures precise alignment, consistent low torque engagement, and protection against contamination for electrical components. Alternative materials or processes could include adjustable brackets, magnetic strips, or standardized', ' The patented spring lock interface engagement system securely attaches two components, such as a test adapter and receiver, ensuring precise alignment, consistent low torque engagement, and protection against contamination for electrical components. It uses a spring lock nut and an Acme lead screw mechanism with multi-start threads to achieve this result. Alternative materials or processes could include adjustable brackets, magnetic strips, or standardized slots or holes.', ' Alternative materials or processes for the spring lock interface engagement system could include adjustable brackets, magnetic strips, standardized slots or holes, and other mechanical fastening methods that provide secure attachment, precise alignment, and protection against contamination for electrical components. These alternatives should also offer consistent low torque engagement and a sealed environment to prevent lubrication contamination.']
